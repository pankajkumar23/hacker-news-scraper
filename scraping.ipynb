# %% [markdown]
# <a href="https://colab.research.google.com/github/pankajkumar23/hacker-news-scraper/blob/main/scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
url="https://news.ycombinator.com"
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')
titles = soup.find_all('span',class_="titleline")
scores = soup.find_all('span', class_='score')
for title,score in zip(titles[:10],scores[:10]):
  print(title.text,score.text)
# Out:
# DaVinci Resolve releases Photo Editor (blackmagicdesign.com) 337 points
# A new spam policy for "back button hijacking" (developers.google.com) 198 points
# Someone bought 30 WordPress plugins and planted a backdoor in all of them (anchor.host) 861 points
# GitHub Stacked PRs (github.github.com) 630 points
# Sometimes powerful people just do dumb shit (joanwestenberg.com) 104 points
# Lean proved this program correct; then I found a bug (kirancodes.me) 205 points
# Can Claude Fly a Plane? (thanks.fish) 6 points
# TanStack Start Now Support React Server Components (tanstack.com) 23 points
# WiiFin – Jellyfin Client for Nintendo Wii (github.com/fabienmillet) 124 points
# Multi-Agentic Software Development Is a Distributed Systems Problem (kirancodes.me) 9 points

# %%
import csv
with open("file.csv",'w') as f:
  writer = csv.writer(f)
  writer.writerow(['Title','Link','Score'])
  for title,score in zip(titles[:10],scores[:10]):
      name = title.text
      link= title.find('a')['href']
      points = score.text
      writer.writerow([name,link,points])

print("file is saved ")
# Out:
# file is saved

# %%
import pandas as pd
df = pd.read_csv("file.csv")
print(df)
# Out:
#                                                Title  \
# 0  DaVinci Resolve releases Photo Editor (blackma...
# 1  A new spam policy for "back button hijacking" ...
# 2  Someone bought 30 WordPress plugins and plante...
# 3             GitHub Stacked PRs (github.github.com)
# 4  Sometimes powerful people just do dumb shit (j...
# 5  Lean proved this program correct; then I found...
# 6              Can Claude Fly a Plane? (thanks.fish)
# 7  TanStack Start Now Support React Server Compon...
# 8  WiiFin – Jellyfin Client for Nintendo Wii (git...
# 9  Multi-Agentic Software Development Is a Distri...
#
#                                                 Link       Score
# 0  https://www.blackmagicdesign.com/products/davi...  337 points
# 1  https://developers.google.com/search/blog/2026...  198 points
# 2  https://anchor.host/someone-bought-30-wordpres...  861 points
# 3                https://github.github.com/gh-stack/  630 points
# ...
